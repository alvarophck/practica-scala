// %%
1 + 1
// Out:
// res1: Int = 2

// %%
val nombre = "Scala"
val version = "2.12.20"
println(s"Hola desde $nombre $version")
// Out:
// Hola desde Scala 2.12.20
// nombre: String = "Scala"
// version: String = "2.12.20"

// %%
val a = 10
val b = 20
val resultado = a + b
println(resultado)
// Out:
// 30
// a: Int = 10
// b: Int = 20
// resultado: Int = 30

// %%
val lenguajes = List("Scala", "Java", "Python")
println(lenguajes)
// Out:
// List(Scala, Java, Python)
// lenguajes: List[String] = List("Scala", "Java", "Python")

// %%
util.Properties.versionString
// Out:
// cmd5.sc:1: object Properties is not a member of package ammonite.util
// val res5 = util.Properties.versionString
//                 ^
// Compilation Failed

// %%
scala.util.Properties.versionString
// Out:
// res5: String = "version 2.12.20"
